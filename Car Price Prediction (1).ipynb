# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
data=pd.read_csv("/Users/mac/Downloads/archive (12)/CarPrice_Assignment.csv")

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data["CarName"].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
data["Company"]=data["CarName"].apply(lambda x : x.split(' ')[0])

# %%
data["Company"]
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: Company, Length: 205, dtype: object

# %%
data.drop(["CarName","car_ID"],axis=1,inplace=True)

# %%
data
# Out:
#      symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0            3      gas        std        two  convertible        rwd
# 1            3      gas        std        two  convertible        rwd
# 2            1      gas        std        two    hatchback        rwd
# 3            2      gas        std       four        sedan        fwd
# 4            2      gas        std       four        sedan        4wd
# ..         ...      ...        ...        ...          ...        ...
# 200         -1      gas        std       four        sedan        rwd
# 201         -1      gas      turbo       four        sedan        rwd
# 202         -1      gas        std       four        sedan        rwd
# 203         -1   diesel      turbo       four        sedan        rwd
# 204         -1      gas      turbo       four        sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  fuelsystem  \
# ...

# %%
#Cars are initially assigned a risk factor symbol associated with its price.
#A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.


data["symboling"].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
data["Company"].value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# volkswagen      9
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# isuzu           4
# porsche         4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# vw              2
# maxda           2
# renault         2
# toyouta         1
# vokswagen       1
# Nissan          1
# mercury         1
# porcshce        1
# Name: Company, dtype: int64

# %%
data["Company"].replace("toyouta","toyota",inplace=True)
data["Company"].replace("porcshce","porsche",inplace=True)
data["Company"].replace("maxda","mazda",inplace=True)
data["Company"].replace("vokswagen","volkswagen",inplace=True)
data["Company"].replace("vw","volkswagen",inplace=True)

# %%
data["Company"].value_counts()
# Out:
# toyota         32
# mazda          17
# nissan         17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Nissan          1
# Name: Company, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.distplot(data["price"])
plt.title("Car Price Distribution")
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Car Price Distribution')

# %%
#Right Skewed Data

# %%
sns.boxplot(data["price"])
plt.title("Car Price Spread")
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Car Price Spread')

# %%
data["price"].describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
data["price"].describe(percentiles=[0.85,0.90,0.95])
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 50%      10295.000000
# 85%      18500.000000
# 90%      22563.000000
# 95%      32472.400000
# max      45400.000000
# Name: price, dtype: float64

# %%
# 85% of cars are in the price range between 0-18,500, the other 15% cars are 
# in the range of 18500-45400

# %%
features = data.select_dtypes(object)

# %%
features
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#     enginetype cylindernumber fuelsystem      Company
# ...

# %%
plt.figure(figsize=(15,10))
features["Company"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
features["aspiration"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
features["carbody"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
features["doornumber"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
data["symboling"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
numeric1= data.select_dtypes(int)

# %%
numeric1
# Out:
#      symboling  curbweight  enginesize  horsepower  peakrpm  citympg  \
# 0            3        2548         130         111     5000       21
# 1            3        2548         130         111     5000       21
# 2            1        2823         152         154     5000       19
# 3            2        2337         109         102     5500       24
# 4            2        2824         136         115     5500       18
# ..         ...         ...         ...         ...      ...      ...
# 200         -1        2952         141         114     5400       23
# 201         -1        3049         141         160     5300       19
# 202         -1        3012         173         134     5500       18
# 203         -1        3217         145         106     4800       26
# 204         -1        3062         141         114     5400       19
#
#      highwaympg
# 0            27
# 1            27
# 2            26
# 3            30
# 4            22
# ..          ...
# ...

# %%
numeric2= data.select_dtypes(float)

# %%
numeric2
# Out:
#      wheelbase  carlength  carwidth  carheight  boreratio  stroke  \
# 0         88.6      168.8      64.1       48.8       3.47    2.68
# 1         88.6      168.8      64.1       48.8       3.47    2.68
# 2         94.5      171.2      65.5       52.4       2.68    3.47
# 3         99.8      176.6      66.2       54.3       3.19    3.40
# 4         99.4      176.6      66.4       54.3       3.19    3.40
# ..         ...        ...       ...        ...        ...     ...
# 200      109.1      188.8      68.9       55.5       3.78    3.15
# 201      109.1      188.8      68.8       55.5       3.78    3.15
# 202      109.1      188.8      68.9       55.5       3.58    2.87
# 203      109.1      188.8      68.9       55.5       3.01    3.40
# 204      109.1      188.8      68.9       55.5       3.78    3.15
#
#      compressionratio    price
# 0                 9.0  13495.0
# 1                 9.0  16500.0
# 2                 9.0  16500.0
# 3                10.0  13950.0
# ...

# %%
numeric=pd.concat([numeric1,numeric2],axis=1)

# %%
numeric
# Out:
#      symboling  curbweight  enginesize  horsepower  peakrpm  citympg  \
# 0            3        2548         130         111     5000       21
# 1            3        2548         130         111     5000       21
# 2            1        2823         152         154     5000       19
# 3            2        2337         109         102     5500       24
# 4            2        2824         136         115     5500       18
# ..         ...         ...         ...         ...      ...      ...
# 200         -1        2952         141         114     5400       23
# 201         -1        3049         141         160     5300       19
# 202         -1        3012         173         134     5500       18
# 203         -1        3217         145         106     4800       26
# 204         -1        3062         141         114     5400       19
#
#      highwaympg  wheelbase  carlength  carwidth  carheight  boreratio  stroke  \
# ...

# %%
sns.boxplot(numeric["curbweight"])
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='curbweight'>

# %%
sns.boxplot(numeric["peakrpm"])
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='peakrpm'>

# %%
bp=numeric.drop(["price","curbweight","peakrpm"],axis=1)

# %%
bp.boxplot(figsize=(25,8))
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(bp["stroke"])
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='stroke'>

# %%
sns.boxplot(bp["compressionratio"])
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='compressionratio'>

# %%
df1=pd.DataFrame(data.groupby(["Company"])["price"].mean())

# %%
df1
# Out:
#                     price
# Company
# Nissan        5499.000000
# alfa-romero  15498.333333
# audi         17859.166714
# bmw          26118.750000
# buick        33647.000000
# chevrolet     6007.000000
# dodge         7875.444444
# honda         8184.692308
# isuzu         8916.500000
# jaguar       34600.000000
# mazda        10652.882353
# mercury      16503.000000
# mitsubishi    9239.769231
# nissan       10704.882353
# peugeot      15489.090909
# plymouth      7963.428571
# porsche      31400.500000
# renault       9595.000000
# saab         15223.333333
# subaru        8541.250000
# toyota        9885.812500
# volkswagen   10077.500000
# volvo        18063.181818

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:xlabel='Company'>

# %%
df2=pd.DataFrame(data.groupby(["fueltype"])["price"].mean())

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:xlabel='fueltype'>

# %%
df3=pd.DataFrame(data.groupby(["carbody"])["price"].mean())

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:xlabel='carbody'>

# %%
corrmat=numeric.corr()

# %%
numeric
# Out:
#      symboling  curbweight  enginesize  horsepower  peakrpm  citympg  \
# 0            3        2548         130         111     5000       21
# 1            3        2548         130         111     5000       21
# 2            1        2823         152         154     5000       19
# 3            2        2337         109         102     5500       24
# 4            2        2824         136         115     5500       18
# ..         ...         ...         ...         ...      ...      ...
# 200         -1        2952         141         114     5400       23
# 201         -1        3049         141         160     5300       19
# 202         -1        3012         173         134     5500       18
# 203         -1        3217         145         106     4800       26
# 204         -1        3062         141         114     5400       19
#
#      highwaympg  wheelbase  carlength  carwidth  carheight  boreratio  stroke  \
# ...

# %%
plt.subplots(figsize=(20,10))
sns.barplot(x=corrmat.index,y=corrmat["price"])
# Out:
# <AxesSubplot:ylabel='price'>

# %%
features
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#     enginetype cylindernumber fuelsystem      Company
# ...

# %%
features["fuelsystem"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
new = data[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                     'carlength','carwidth']]

# %%
new
# Out:
#        price fueltype aspiration      carbody drivewheel  wheelbase  \
# 0    13495.0      gas        std  convertible        rwd       88.6
# 1    16500.0      gas        std  convertible        rwd       88.6
# 2    16500.0      gas        std    hatchback        rwd       94.5
# 3    13950.0      gas        std        sedan        fwd       99.8
# 4    17450.0      gas        std        sedan        4wd       99.4
# ..       ...      ...        ...          ...        ...        ...
# 200  16845.0      gas        std        sedan        rwd      109.1
# 201  19045.0      gas      turbo        sedan        rwd      109.1
# 202  21485.0      gas        std        sedan        rwd      109.1
# 203  22470.0   diesel      turbo        sedan        rwd      109.1
# 204  22625.0      gas      turbo        sedan        rwd      109.1
#
#      curbweight enginetype cylindernumber  enginesize  boreratio  horsepower  \
# ...

# %%
sns.pairplot(new)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lc=LabelEncoder()

# %%
for col in new.select_dtypes(include=['object']):
    new[col+'_encoded'] = lc.fit_transform( new[col])
# Out:
# /var/folders/dj/64959mgn5j30w6bm8cj8j1340000gn/T/ipykernel_1913/306372935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[col+'_encoded'] = lc.fit_transform( new[col])
# /var/folders/dj/64959mgn5j30w6bm8cj8j1340000gn/T/ipykernel_1913/306372935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new[col+'_encoded'] = lc.fit_transform( new[col])
# /var/folders/dj/64959mgn5j30w6bm8cj8j1340000gn/T/ipykernel_1913/306372935.py:2: SettingWithCopyWarning:
# ...

# %%
new
# Out:
#        price fueltype aspiration      carbody drivewheel  wheelbase  \
# 0    13495.0      gas        std  convertible        rwd       88.6
# 1    16500.0      gas        std  convertible        rwd       88.6
# 2    16500.0      gas        std    hatchback        rwd       94.5
# 3    13950.0      gas        std        sedan        fwd       99.8
# 4    17450.0      gas        std        sedan        4wd       99.4
# ..       ...      ...        ...          ...        ...        ...
# 200  16845.0      gas        std        sedan        rwd      109.1
# 201  19045.0      gas      turbo        sedan        rwd      109.1
# 202  21485.0      gas        std        sedan        rwd      109.1
# 203  22470.0   diesel      turbo        sedan        rwd      109.1
# 204  22625.0      gas      turbo        sedan        rwd      109.1
#
#      curbweight enginetype cylindernumber  enginesize  boreratio  horsepower  \
# ...

# %%
new.drop(["fueltype","aspiration","carbody","drivewheel","enginetype","cylindernumber"],axis=1,inplace=True)
# Out:
# /var/folders/dj/64959mgn5j30w6bm8cj8j1340000gn/T/ipykernel_1913/1139513641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new.drop(["fueltype","aspiration","carbody","drivewheel","enginetype","cylindernumber"],axis=1,inplace=True)

# %%
new
# Out:
#        price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 0    13495.0       88.6        2548         130       3.47         111
# 1    16500.0       88.6        2548         130       3.47         111
# 2    16500.0       94.5        2823         152       2.68         154
# 3    13950.0       99.8        2337         109       3.19         102
# 4    17450.0       99.4        2824         136       3.19         115
# ..       ...        ...         ...         ...        ...         ...
# 200  16845.0      109.1        2952         141       3.78         114
# 201  19045.0      109.1        3049         141       3.78         160
# 202  21485.0      109.1        3012         173       3.58         134
# 203  22470.0      109.1        3217         145       3.01         106
# 204  22625.0      109.1        3062         141       3.78         114
#
#      carlength  carwidth  fueltype_encoded  aspiration_encoded  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df_train,df_test=train_test_split(new,train_size=0.7,test_size=0.3,random_state=100)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','carlength','carwidth','price']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train
# Out:
#         price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 122 -0.700201  -0.811836   -0.642128   -0.660242  -1.297329   -0.872898
# 125  1.151929  -0.677177    0.439415    0.637806   2.432256    1.021826
# 166 -0.452248  -0.677177   -0.441296   -0.660242  -0.259197    0.238673
# 1    0.442646  -1.670284    0.015642    0.123485   0.625138    0.213410
# 199  0.757569   0.972390    1.137720    0.123485   1.201877    1.501822
# ..        ...        ...         ...         ...        ...         ...
# 87  -0.485539  -0.374195   -0.251520   -0.366345  -0.528342    0.339725
# 103  0.056898   0.315930    0.958998    1.372551   0.471340    1.249192
# 67   1.606189   1.931832    1.797333    1.421534   1.048080    0.516566
# 24  -0.877586  -0.811836   -1.054847   -0.856174  -1.297329   -0.872898
# 8    1.390627   1.224875    1.006903    0.147977  -0.682139    0.946037
#
#      carlength  carwidth  fueltype_encoded  aspiration_encoded  \
# ...

# %%
x_train=df_train
y_train=df_train.pop("price")

# %%
x_train
# Out:
#      wheelbase  curbweight  enginesize  boreratio  horsepower  carlength  \
# 122  -0.811836   -0.642128   -0.660242  -1.297329   -0.872898  -0.487238
# 125  -0.677177    0.439415    0.637806   2.432256    1.021826  -0.359789
# 166  -0.677177   -0.441296   -0.660242  -0.259197    0.238673  -0.375720
# 1    -1.670284    0.015642    0.123485   0.625138    0.213410  -0.367754
# 199   0.972390    1.137720    0.123485   1.201877    1.501822   1.225364
# ..         ...         ...         ...        ...         ...        ...
# 87   -0.374195   -0.251520   -0.366345  -0.528342    0.339725  -0.080993
# 103   0.315930    0.958998    1.372551   0.471340    1.249192   0.890809
# 67    1.931832    1.797333    1.421534   1.048080    0.516566   1.392642
# 24   -0.811836   -1.054847   -0.856174  -1.297329   -0.872898  -1.283797
# 8     1.224875    1.006903    0.147977  -0.682139    0.946037   1.536022
#
#      carwidth  fueltype_encoded  aspiration_encoded  carbody_encoded  \
# ...

# %%
y_train
# Out:
# 122   -0.700201
# 125    1.151929
# 166   -0.452248
# 1      0.442646
# 199    0.757569
#          ...
# 87    -0.485539
# 103    0.056898
# 67     1.606189
# 24    -0.877586
# 8      1.390627
# Name: price, Length: 143, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.843867747005506

# %%
scaler2 = StandardScaler()
num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','carlength','carwidth','price']
df_test[num_vars] = scaler2.fit_transform(df_test[num_vars])

# %%
x_test=df_test
y_test=df_test.pop("price")

# %%
y_pred=reg.predict(x_test)

# %%
y_pred
# Out:
# array([-0.92742464, -0.57348315, -0.35229831, -0.5752546 , -0.94303916,
#        -0.32956673,  0.70783798,  0.8779889 ,  0.57361535,  1.27243407,
#         0.60179098,  0.10488226,  0.35408671, -0.37262299,  3.17012121,
#        -1.04270045, -0.9348124 , -0.09633611,  0.30165746,  0.45481112,
#         0.43776388,  0.4423102 ,  1.26425076, -1.03394565,  0.27118856,
#         0.96433711,  0.58405375,  1.60922004, -0.27925753, -0.04527314,
#        -0.96897456,  1.51015268,  0.815771  ,  0.88826364,  0.36859018,
#        -0.33156273,  0.14357527,  0.22221881, -1.06976466, -0.32527416,
#         3.09844597, -0.35856087, -0.86367937, -0.42999334, -1.16738483,
#        -0.38053937, -1.04881804, -0.28436081, -0.65411782, -0.60287814,
#        -1.03179589,  0.2689154 , -0.66561663, -0.45049988,  0.54572647,
#        -0.65054576, -0.40331997, -0.40154126,  0.39052058, -0.65582269,
#        -0.70130541,  1.34447643])

# %%
cc=y_test.values

# %%
cc
# Out:
# array([-0.72260072, -0.63214071, -0.5903164 , -0.5361838 , -0.73873295,
#        -0.30352114,  0.55387721,  0.32479949,  0.4641342 ,  0.40797012,
#         0.36566782,  0.52161275,  0.21450282, -0.10037449,  3.24736277,
#        -0.82811748, -0.81819914, -0.19298546,  0.53714749,  0.12953972,
#        -0.04421042,  0.32623347,  2.23975539, -0.98143345, -0.63763762,
#        -0.03417258, -0.12200363,  1.71969998,  0.37522766, -0.32706225,
#        -0.90770317,  2.02848288,  0.00896621,  0.62856348,  0.33997574,
#        -0.36888656,  0.14997388, -0.45361066, -0.82883447, -0.57800811,
#         3.77793401,  0.01972103, -0.78712966, -0.63166272, -1.00210661,
#        -0.57788861, -0.73801597, -0.53845426, -0.69188973, -0.51264269,
#        -0.83528736, -0.49543497, -0.66285171, -0.45289367,  0.61362623,
#        -0.70348104, -0.58123455, -0.58123455, -0.09810403, -0.71817929,
#        -0.41704426,  2.77749652])

# %%
cc.reshape(-1,1)
# Out:
# array([[-0.72260072],
#        [-0.63214071],
#        [-0.5903164 ],
#        [-0.5361838 ],
#        [-0.73873295],
#        [-0.30352114],
#        [ 0.55387721],
#        [ 0.32479949],
#        [ 0.4641342 ],
#        [ 0.40797012],
#        [ 0.36566782],
#        [ 0.52161275],
#        [ 0.21450282],
#        [-0.10037449],
#        [ 3.24736277],
#        [-0.82811748],
#        [-0.81819914],
#        [-0.19298546],
#        [ 0.53714749],
#        [ 0.12953972],
#        [-0.04421042],
#        [ 0.32623347],
#        [ 2.23975539],
#        [-0.98143345],
#        [-0.63763762],
#        [-0.03417258],
#        [-0.12200363],
#        [ 1.71969998],
#        [ 0.37522766],
#        [-0.32706225],
#        [-0.90770317],
#        [ 2.02848288],
#        [ 0.00896621],
#        [ 0.62856348],
#        [ 0.33997574],
#        [-0.36888656],
#        [ 0.14997388],
#        [-0.45361066],
#        [-0.82883447],
#        [-0.57800811],
#        [ 3.77793401],
# ...

# %%
y_pred.reshape(-1,1)
# Out:
# array([[-0.92742464],
#        [-0.57348315],
#        [-0.35229831],
#        [-0.5752546 ],
#        [-0.94303916],
#        [-0.32956673],
#        [ 0.70783798],
#        [ 0.8779889 ],
#        [ 0.57361535],
#        [ 1.27243407],
#        [ 0.60179098],
#        [ 0.10488226],
#        [ 0.35408671],
#        [-0.37262299],
#        [ 3.17012121],
#        [-1.04270045],
#        [-0.9348124 ],
#        [-0.09633611],
#        [ 0.30165746],
#        [ 0.45481112],
#        [ 0.43776388],
#        [ 0.4423102 ],
#        [ 1.26425076],
#        [-1.03394565],
#        [ 0.27118856],
#        [ 0.96433711],
#        [ 0.58405375],
#        [ 1.60922004],
#        [-0.27925753],
#        [-0.04527314],
#        [-0.96897456],
#        [ 1.51015268],
#        [ 0.815771  ],
#        [ 0.88826364],
#        [ 0.36859018],
#        [-0.33156273],
#        [ 0.14357527],
#        [ 0.22221881],
#        [-1.06976466],
#        [-0.32527416],
#        [ 3.09844597],
# ...

# %%
mse = np.mean(np.square(cc - y_pred))

# %%
mse
# Out:
# 0.1833401304083527
